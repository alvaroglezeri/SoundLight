# %%
from core.model.lightGroups import LightManager
from core.model.fixtures import *

# %%
lm = LightManager()
pc = ParCan()


left = lm.createFixtures(ParCan, 4)
right = lm.createFixtures(ParCan, 4)


print(lm)
# Out:
# [SUCC] at LightManager.__new__: Created Light Manager
# --- LightManager ---
#  > Fixtures:
#     ParCan: 8
#
#  > Groups:
# -
