# %%
from core.soundlight import SoundLight

sl = SoundLight()

sl.addSongFromPath(
    r"/home/alvaro/Escritorio/SoundLight/SoundLight/resources/CamelPhat, Yannis, Foals - Hypercolour.mp3")
sl.selectSong(0)

# sl._printSongMetadata()

sl.analyze()
sl.generate()
sl.export(r"output/")
